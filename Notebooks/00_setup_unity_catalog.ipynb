# %%
# %sql

CREATE CATALOG IF NOT EXISTS retail_capstone;

CREATE SCHEMA IF NOT EXISTS retail_capstone.bronze;
CREATE SCHEMA IF NOT EXISTS retail_capstone.silver;
CREATE SCHEMA IF NOT EXISTS retail_capstone.gold;

# %%
df_orders_silver.write.mode("overwrite").saveAsTable("retail_capstone.silver.orders")

# %%
df_fact_final.write.mode("overwrite").saveAsTable("retail_capstone.gold.fact_retail")

# %%
# %sql
GRANT SELECT ON SCHEMA retail_capstone.gold TO 'data_analyst_role';
GRANT ALL PRIVILEGES ON SCHEMA retail_capstone.gold TO 'data_engineer_role';
